# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagah1/Sales_insights/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/Sales_April_2019.csv')

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.dropna()
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.drop_duplicates()
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.dropna()
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.describe()
# Out:
#         Order ID                   Product Quantity Ordered Price Each  \
# count      18324                     18324            18324      18324
# unique     17538                        20                8         19
# top     Order ID  Lightning Charging Cable                1      14.95
# freq          35                      2201            16558       2201
#
#         Order Date  Purchase Address
# count        18324             18324
# unique       13584             17120
# top     Order Date  Purchase Address
# freq            35                35

# %%
data.isnull().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64

# %%
data.dropna()
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.to_csv('april_1')

# %%
data2 = pd.read_csv('/content/april_1')

# %%
data2
# Out:
#        Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0               0   176558        USB-C Charging Cable                2
# 1               2   176559  Bose SoundSport Headphones                1
# 2               3   176560                Google Phone                1
# 3               4   176560            Wired Headphones                1
# 4               5   176561            Wired Headphones                1
# ...           ...      ...                         ...              ...
# 18263       18378   194090                Google Phone                1
# 18264       18379   194091       AA Batteries (4-pack)                1
# 18265       18380   194092      AAA Batteries (4-pack)                2
# 18266       18381   194093       AA Batteries (4-pack)                1
# 18267       18382   194094    Lightning Charging Cable                1
#
#       Price Each      Order Date                        Purchase Address
# ...

# %%
new = pd.read_csv('/content/Sales_May_2019.csv.....csv')

# %%
new
# Out:
#        Order ID  Len                     Product  Quantity Ordered  \
# 0        194095    1            Wired Headphones                 1
# 1        194096    1       AA Batteries (4-pack)                 1
# 2        194097    1            27in FHD Monitor                 1
# 3        194098    1            Wired Headphones                 1
# 4        194099    1      AAA Batteries (4-pack)                 2
# ...         ...  ...                         ...               ...
# 16497    209916    1  Bose SoundSport Headphones                 1
# 16498    209917    1            Wired Headphones                 1
# 16499    209918    1      AAA Batteries (4-pack)                 2
# 16500    209919    1        USB-C Charging Cable                 1
# 16501    209920    1             ThinkPad Laptop                 1
#
#        Price Each   Total Month       Order Date Purchase Address  \
# 0           11.99   11.99   May  5/16/2019 17:14       669 2nd St
# ...

# %%
new.isnull().sum()
# Out:
# Order ID            0
# Len                 0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Total               0
# Month               0
# Order Date          0
# Purchase Address    0
# Country             0
# State               0
# number of state     0
# dtype: int64

# %%
new.drop_duplicates()
# Out:
#        Order ID  Len                     Product  Quantity Ordered  \
# 0        194095    1            Wired Headphones                 1
# 1        194096    1       AA Batteries (4-pack)                 1
# 2        194097    1            27in FHD Monitor                 1
# 3        194098    1            Wired Headphones                 1
# 4        194099    1      AAA Batteries (4-pack)                 2
# ...         ...  ...                         ...               ...
# 16497    209916    1  Bose SoundSport Headphones                 1
# 16498    209917    1            Wired Headphones                 1
# 16499    209918    1      AAA Batteries (4-pack)                 2
# 16500    209919    1        USB-C Charging Cable                 1
# 16501    209920    1             ThinkPad Laptop                 1
#
#        Price Each   Total Month       Order Date Purchase Address  \
# 0           11.99   11.99   May  5/16/2019 17:14       669 2nd St
# ...

# %%
new.to_excel
# Out:
# <bound method NDFrame.to_excel of        Order ID  Len                     Product  Quantity Ordered  \
# 0        194095    1            Wired Headphones                 1
# 1        194096    1       AA Batteries (4-pack)                 1
# 2        194097    1            27in FHD Monitor                 1
# 3        194098    1            Wired Headphones                 1
# 4        194099    1      AAA Batteries (4-pack)                 2
# ...         ...  ...                         ...               ...
# 16497    209916    1  Bose SoundSport Headphones                 1
# 16498    209917    1            Wired Headphones                 1
# 16499    209918    1      AAA Batteries (4-pack)                 2
# 16500    209919    1        USB-C Charging Cable                 1
# 16501    209920    1             ThinkPad Laptop                 1
#
#        Price Each   Total Month       Order Date Purchase Address  \
# ...

# %%
new.to_csv('new_may')

# %%
feb = pd.read_csv('/content/Sales_February_2019.csv')

# %%
feb
# Out:
#        Order ID                 Product  lenth  Quantity Ordered  Price Each  \
# 0        160509  AAA Batteries (4-pack)      1                 2        2.99
# 1        156889    USB-C Charging Cable      1                 1       11.95
# 2        156342    USB-C Charging Cable      1                 1       11.95
# 3        159193    USB-C Charging Cable      1                 1       11.95
# 4        159327  AAA Batteries (4-pack)      1                 1        2.99
# ...         ...                     ...    ...               ...         ...
# 11981    150533  AAA Batteries (4-pack)      1                 1        2.99
# 11982    159347  AAA Batteries (4-pack)      1                 1        2.99
# 11983    153284        Wired Headphones      1                 1       11.99
# 11984    158262        Wired Headphones      1                 1       11.99
# 11985    152036         ThinkPad Laptop      1                 1      999.99
#
# ...

# %%
feb.describe()
# Out:
#             Order ID    lenth  Quantity Ordered    Price Each  \
# count   11986.000000  11986.0       11986.00000  11986.000000
# mean   156250.613382      1.0           1.12306    182.741507
# std      3322.075263      0.0           0.43111    325.543296
# min    150502.000000      1.0           1.00000      2.990000
# 25%    153374.250000      1.0           1.00000     11.950000
# 50%    156247.500000      1.0           1.00000     14.950000
# 75%    159123.750000      1.0           1.00000    150.000000
# max    162008.000000      1.0           7.00000   1700.000000
#
#        Total of Amount  number of state
# count     11986.000000     11986.000000
# mean        183.837914     64007.663608
# std         325.589573     37738.476048
# min           2.990000      2215.000000
# 25%          11.950000     10001.000000
# 50%          14.950000     90001.000000
# 75%         150.000000     94016.000000
# max        1700.000000     98101.000000

# %%
feb.drop_duplicates()
# Out:
#        Order ID                 Product  lenth  Quantity Ordered  Price Each  \
# 0        160509  AAA Batteries (4-pack)      1                 2        2.99
# 1        156889    USB-C Charging Cable      1                 1       11.95
# 2        156342    USB-C Charging Cable      1                 1       11.95
# 3        159193    USB-C Charging Cable      1                 1       11.95
# 4        159327  AAA Batteries (4-pack)      1                 1        2.99
# ...         ...                     ...    ...               ...         ...
# 11981    150533  AAA Batteries (4-pack)      1                 1        2.99
# 11982    159347  AAA Batteries (4-pack)      1                 1        2.99
# 11983    153284        Wired Headphones      1                 1       11.99
# 11984    158262        Wired Headphones      1                 1       11.99
# 11985    152036         ThinkPad Laptop      1                 1      999.99
#
# ...

# %%
feb.to_csv('feb1')

# %%
jan = pd.read_csv('/content/Sales_January_2019.csv')

# %%
jan
# Out:
#       Order ID                   Product  lenth  Quantity Ordered  Price Each  \
# 0       141234                    iPhone      1                 1      700.00
# 1       141235  Lightning Charging Cable      1                 1       14.95
# 2       141236          Wired Headphones      1                 2       11.99
# 3       141237          27in FHD Monitor      1                 1      149.99
# 4       141238          Wired Headphones      1                 1       11.99
# ...        ...                       ...    ...               ...         ...
# 9676    150497              20in Monitor      1                 1      109.99
# 9677    150498          27in FHD Monitor      1                 1      149.99
# 9678    150499           ThinkPad Laptop      1                 1      999.99
# 9679    150500    AAA Batteries (4-pack)      1                 2        2.99
# 9680    150501              Google Phone      1                 1      600.00
#
# ...

# %%
jan.isnull().sum()
# Out:
# Order ID            0
# Product             0
# lenth               0
# Quantity Ordered    0
# Price Each          0
# Total               0
# Order Date          0
# Month               0
# Purchase Address    0
# Country             0
# State               0
# Number of state     0
# dtype: int64

# %%
jan.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-d448fd908054> in <cell line: 1>()
# ----> 1 jan = drop_duplicates()
#
# NameError: name 'drop_duplicates' is not defined

# %%
jan.to_csv('jan1')

# %%
june = pd.read_csv('/content/Sales_June_2019.csv')

# %%
june
# Out:
#        Order ID                   Product  lenth  Quantity Ordered  \
# 0        217932  Lightning Charging Cable      1                 2
# 1        220585  Apple Airpods Headphones      1                 1
# 2        209977     AA Batteries (4-pack)      1                 1
# 3        222469                    iPhone      1                 1
# 4        222469  Lightning Charging Cable      1                 1
# ...         ...                       ...    ...               ...
# 13284  Order ID                   Product     16  Quantity Ordered
# 13285  Order ID                   Product     16  Quantity Ordered
# 13286  Order ID                   Product     16  Quantity Ordered
# 13287  Order ID                   Product     16  Quantity Ordered
# 13288  Order ID                   Product     16  Quantity Ordered
#
#        Price Each    Total       Month     Order Date  Purchase Address  \
# 0           14.95     29.9        June  6/1/2019 4:52     653 Forest St
# ...

# %%
june.describe()
# Out:
#               lenth  Number of State
# count  13289.000000     13266.000000
# mean       1.025961     64269.945500
# std        0.623518     37609.255923
# min        1.000000      2215.000000
# 25%        1.000000     30301.000000
# 50%        1.000000     90001.000000
# 75%        1.000000     94016.000000
# max       16.000000     98101.000000

# %%
june.isnull().sum()
# Out:
# Order ID             0
# Product              0
# lenth                0
# Quantity Ordered     0
# Price Each           0
# Total                0
# Month                0
# Order Date           0
# Purchase Address     0
# Country             23
# State               23
# Number of State     23
# dtype: int64

# %%
jun = june.dropna()

# %%
jun.isnull().sum()
# Out:
# Order ID            0
# Product             0
# lenth               0
# Quantity Ordered    0
# Price Each          0
# Total               0
# Month               0
# Order Date          0
# Purchase Address    0
# Country             0
# State               0
# Number of State     0
# dtype: int64

# %%
jun.drop_duplicates()
# Out:
#       Order ID                     Product  lenth Quantity Ordered Price Each  \
# 0       217932    Lightning Charging Cable      1                2      14.95
# 1       220585    Apple Airpods Headphones      1                1        150
# 2       209977       AA Batteries (4-pack)      1                1       3.84
# 3       222469                      iPhone      1                1        700
# 4       222469    Lightning Charging Cable      1                1      14.95
# ...        ...                         ...    ...              ...        ...
# 13261   213660        USB-C Charging Cable      1                1      11.95
# 13262   216431             Vareebadd Phone      1                1        400
# 13263   216431                Google Phone      1                1        600
# 13264   214986  Bose SoundSport Headphones      1                1      99.99
# 13265   218457      27in 4K Gaming Monitor      1                1     389.99
#
# ...

# %%
jun.to_csv('june')

# %%
march = pd.read_csv('/content/Sales_March_2019.csv')

# %%
march
# Out:
#        Order ID                     Product  lenth  Quantity Ordered  \
# 0        175045        USB-C Charging Cable      1                 1
# 1        170411            Wired Headphones      1                 1
# 2        171218        USB-C Charging Cable      1                 1
# 3        173057                      iPhone      1                 1
# 4        165475       AA Batteries (4-pack)      1                 1
# ...         ...                         ...    ...               ...
# 15149    166309       AA Batteries (4-pack)      1                 1
# 15150    175769  Bose SoundSport Headphones      1                 1
# 15151    167813      27in 4K Gaming Monitor      1                 1
# 15152    165622    Lightning Charging Cable      1                 1
# 15153    174575       AA Batteries (4-pack)      1                 1
#
#        Price Each   Total  Month     Order Date  Purchase Address  \
# 0           11.95   11.95  March  3/1/2019 3:15  233 Jefferson St
# ...

# %%
  marc = march.drop_duplicates()

# %%
marc
# Out:
#        Order ID                     Product  lenth  Quantity Ordered  \
# 0        175045        USB-C Charging Cable      1                 1
# 1        170411            Wired Headphones      1                 1
# 2        171218        USB-C Charging Cable      1                 1
# 3        173057                      iPhone      1                 1
# 4        165475       AA Batteries (4-pack)      1                 1
# ...         ...                         ...    ...               ...
# 15149    166309       AA Batteries (4-pack)      1                 1
# 15150    175769  Bose SoundSport Headphones      1                 1
# 15151    167813      27in 4K Gaming Monitor      1                 1
# 15152    165622    Lightning Charging Cable      1                 1
# 15153    174575       AA Batteries (4-pack)      1                 1
#
#        Price Each   Total  Month     Order Date  Purchase Address  \
# 0           11.95   11.95  March  3/1/2019 3:15  233 Jefferson St
# ...

# %%
marc.to_csv('march')

# %%
april = pd.read_csv('/content/Sales_April_2019.csv')

# %%
april
# Out:
#        Order ID                   Product  lengh  Quantity Ordered  \
# 0        177831  Lightning Charging Cable      1                 1
# 1        177687          Wired Headphones      1                 1
# 2        186754          27in FHD Monitor      1                 1
# 3        185103      USB-C Charging Cable      1                 1
# 4        191585              20in Monitor      1                 1
# ...         ...                       ...    ...               ...
# 18122    181688           ThinkPad Laptop      1                 1
# 18123    189854      USB-C Charging Cable      1                 1
# 18124    181645  Apple Airpods Headphones      1                 1
# 18125    179134  Apple Airpods Headphones      1                 1
# 18126    194067                    iPhone      1                 1
#
#        Price Each  total Amount     Order Date  Month   Purchase Address  \
# 0           14.95         14.95  4/1/2019 3:09  April         914 6th St
# ...

# %%
  ap = april.drop_duplicates()

# %%
ap
# Out:
#        Order ID                   Product  lengh  Quantity Ordered  \
# 0        177831  Lightning Charging Cable      1                 1
# 1        177687          Wired Headphones      1                 1
# 2        186754          27in FHD Monitor      1                 1
# 3        185103      USB-C Charging Cable      1                 1
# 4        191585              20in Monitor      1                 1
# ...         ...                       ...    ...               ...
# 18122    181688           ThinkPad Laptop      1                 1
# 18123    189854      USB-C Charging Cable      1                 1
# 18124    181645  Apple Airpods Headphones      1                 1
# 18125    179134  Apple Airpods Headphones      1                 1
# 18126    194067                    iPhone      1                 1
#
#        Price Each  total Amount     Order Date  Month   Purchase Address  \
# 0           14.95         14.95  4/1/2019 3:09  April         914 6th St
# ...

# %%
ap.to_csv('april')

# %%
august  = pd.read_csv('/content/Sales_August_2019.csv')

# %%
august
# Out:
#       Order ID                   Product  Lenth  Quantity Ordered  Price Each  \
# 0       242859    27in 4K Gaming Monitor      1                 1      389.99
# 1       240817     AA Batteries (4-pack)      1                 1        3.84
# 2       243454  Lightning Charging Cable      1                 1       14.95
# 3       241974          Wired Headphones      1                 1       11.99
# 4       240910             Flatscreen TV      1                 1      300.00
# ...        ...                       ...    ...               ...         ...
# 5656    244953  Lightning Charging Cable      1                 1       14.95
# 5657    243667      USB-C Charging Cable      1                 1       11.95
# 5658    242865          27in FHD Monitor      1                 1      149.99
# 5659    240636  Lightning Charging Cable      1                 1       14.95
# 5660    242343           ThinkPad Laptop      1                 1      999.99
#
# ...

# %%
 aug= august.drop_duplicates()

# %%
aug
# Out:
#       Order ID                   Product  Lenth  Quantity Ordered  Price Each  \
# 0       242859    27in 4K Gaming Monitor      1                 1      389.99
# 1       240817     AA Batteries (4-pack)      1                 1        3.84
# 2       243454  Lightning Charging Cable      1                 1       14.95
# 3       241974          Wired Headphones      1                 1       11.99
# 4       240910             Flatscreen TV      1                 1      300.00
# ...        ...                       ...    ...               ...         ...
# 5656    244953  Lightning Charging Cable      1                 1       14.95
# 5657    243667      USB-C Charging Cable      1                 1       11.95
# 5658    242865          27in FHD Monitor      1                 1      149.99
# 5659    240636  Lightning Charging Cable      1                 1       14.95
# 5660    242343           ThinkPad Laptop      1                 1      999.99
#
# ...

# %%
aug.to_csv('august')

# %%
sept = pd.read_csv('/content/Sales_September_2019.csv')

# %%
sept
# Out:
#        Order ID                     Product  Lenth  Quantity Ordered  \
# 0        248922    Apple Airpods Headphones      1                 1
# 1        258065       AA Batteries (4-pack)      1                 4
# 2        257173        USB-C Charging Cable      1                 1
# 3        251424                20in Monitor      1                 1
# 4        248401            27in FHD Monitor      1                 1
# ...         ...                         ...    ...               ...
# 11624    255614  Bose SoundSport Headphones      1                 1
# 11625    259228       AA Batteries (4-pack)      1                 1
# 11626    257017      AAA Batteries (4-pack)      1                 3
# 11627    250684      AAA Batteries (4-pack)      1                 1
# 11628    253168                20in Monitor      1                 1
#
#        Price Each   Total      Month      Order Date   Purchase Address  \
# ...

# %%
  sep = sept.drop_duplicates()

# %%
sep
# Out:
#        Order ID                     Product  Lenth  Quantity Ordered  \
# 0        248922    Apple Airpods Headphones      1                 1
# 1        258065       AA Batteries (4-pack)      1                 4
# 2        257173        USB-C Charging Cable      1                 1
# 3        251424                20in Monitor      1                 1
# 4        248401            27in FHD Monitor      1                 1
# ...         ...                         ...    ...               ...
# 11624    255614  Bose SoundSport Headphones      1                 1
# 11625    259228       AA Batteries (4-pack)      1                 1
# 11626    257017      AAA Batteries (4-pack)      1                 3
# 11627    250684      AAA Batteries (4-pack)      1                 1
# 11628    253168                20in Monitor      1                 1
#
#        Price Each   Total      Month      Order Date   Purchase Address  \
# ...

# %%
sep.to_csv('sept')

# %%
octo = pd.read_csv('/content/Sales_October_2019.csv')

# %%
octo
# Out:
#        Order ID                     Product  Lenth  Quantity Ordered  \
# 0        269590             ThinkPad Laptop      1                 1
# 1        269164                20in Monitor      1                 1
# 2        264038            Wired Headphones      1                 1
# 3        276847      AAA Batteries (4-pack)      1                 4
# 4        276847            Wired Headphones      1                 2
# ...         ...                         ...    ...               ...
# 20279    273655    Apple Airpods Headphones      1                 1
# 20280    268081  Bose SoundSport Headphones      1                 1
# 20281    277647      27in 4K Gaming Monitor      1                 1
# 20282    262928    Lightning Charging Cable      1                 1
# 20283    275546        USB-C Charging Cable      1                 2
#
#        Price Each   Total     Month      Order Date  Purchase Address  \
# ...

# %%
  oct = octo.drop_duplicates()

# %%
oct
# Out:
#        Order ID                     Product  Lenth  Quantity Ordered  \
# 0        269590             ThinkPad Laptop      1                 1
# 1        269164                20in Monitor      1                 1
# 2        264038            Wired Headphones      1                 1
# 3        276847      AAA Batteries (4-pack)      1                 4
# 4        276847            Wired Headphones      1                 2
# ...         ...                         ...    ...               ...
# 20279    273655    Apple Airpods Headphones      1                 1
# 20280    268081  Bose SoundSport Headphones      1                 1
# 20281    277647      27in 4K Gaming Monitor      1                 1
# 20282    262928    Lightning Charging Cable      1                 1
# 20283    275546        USB-C Charging Cable      1                 2
#
#        Price Each   Total     Month      Order Date  Purchase Address  \
# ...

# %%
oct.to_csv('october')

# %%
nove = pd.read_csv('/content/Sales_November_2019.csv')

# %%
nove
# Out:
#        Order ID                   Product  Lenth  Quantity Ordered  \
# 0        292700    AAA Batteries (4-pack)      1                 2
# 1        292205          27in FHD Monitor      1                 1
# 2        285738  Lightning Charging Cable      1                 1
# 3        283900      USB-C Charging Cable      1                 1
# 4        295315                    iPhone      1                 1
# ...         ...                       ...    ...               ...
# 16031    294629          Wired Headphones      1                 1
# 16032    293713  Apple Airpods Headphones      1                 1
# 16033    280809  Lightning Charging Cable      1                 1
# 16034    293658  Lightning Charging Cable      1                 1
# 16035    283689    AAA Batteries (4-pack)      1                 1
#
#        Price Each   Total      Order Date     Month Purchase Address  \
# 0            2.99    5.98  11/1/2019 3:18  November     586 Ridge St
# ...

# %%
nove.isnull().sum()
# Out:
# Order ID                0
# Product                 0
# Lenth                   0
# Quantity Ordered        0
# Price Each              0
# Total                   0
# Order Date              0
# Month               15798
# Purchase Address        0
# Country                 0
# State                   0
# code                    0
# dtype: int64

# %%
novee = nove.dropna()

# %%
novee
# Out:
#        Order ID                   Product  Lenth  Quantity Ordered  \
# 0        292700    AAA Batteries (4-pack)      1                 2
# 1        292205          27in FHD Monitor      1                 1
# 2        285738  Lightning Charging Cable      1                 1
# 3        283900      USB-C Charging Cable      1                 1
# 4        295315                    iPhone      1                 1
# ...         ...                       ...    ...               ...
# 14007    278805  Lightning Charging Cable      1                 1
# 14476    278841      USB-C Charging Cable      1                 1
# 15369    278823     AA Batteries (4-pack)      1                 1
# 15743    278857      USB-C Charging Cable      1                 1
# 15744    278857    AAA Batteries (4-pack)      1                 2
#
#        Price Each   Total        Order Date     Month Purchase Address  \
# 0            2.99    5.98    11/1/2019 3:18  November     586 Ridge St
# ...

# %%
  nov = novee.drop_duplicates()

# %%
nov
# Out:
#        Order ID                   Product  Lenth  Quantity Ordered  \
# 0        292700    AAA Batteries (4-pack)      1                 2
# 1        292205          27in FHD Monitor      1                 1
# 2        285738  Lightning Charging Cable      1                 1
# 3        283900      USB-C Charging Cable      1                 1
# 4        295315                    iPhone      1                 1
# ...         ...                       ...    ...               ...
# 14007    278805  Lightning Charging Cable      1                 1
# 14476    278841      USB-C Charging Cable      1                 1
# 15369    278823     AA Batteries (4-pack)      1                 1
# 15743    278857      USB-C Charging Cable      1                 1
# 15744    278857    AAA Batteries (4-pack)      1                 2
#
#        Price Each   Total        Order Date     Month Purchase Address  \
# 0            2.99    5.98    11/1/2019 3:18  November     586 Ridge St
# ...

# %%
nov.to_csv('novv')

# %%
dece = pd.read_csv('/content/Sales_December_2019.csv')

# %%
dece
# Out:
#        Order ID                 Product  Lenth  Quantity Ordered  Price Each  \
# 0        301778    USB-C Charging Cable      1                 1       11.95
# 1        309213            Google Phone      1                 1      600.00
# 2        314587  34in Ultrawide Monitor      1                 1      379.99
# 3        315501        Wired Headphones      1                 1       11.99
# 4        312424  AAA Batteries (4-pack)      1                 1        2.99
# ...         ...                     ...    ...               ...         ...
# 24950    297481   AA Batteries (4-pack)      1                 1        3.84
# 24951    298406  AAA Batteries (4-pack)      1                 2        2.99
# 24952    317048  AAA Batteries (4-pack)      1                 2        2.99
# 24953    309773  AAA Batteries (4-pack)      1                 1        2.99
# 24954    297674  AAA Batteries (4-pack)      1                 1        2.99
#
# ...

# %%
  dec = dece.drop_duplicates()

# %%
dec
# Out:
#        Order ID                 Product  Lenth  Quantity Ordered  Price Each  \
# 0        301778    USB-C Charging Cable      1                 1       11.95
# 1        309213            Google Phone      1                 1      600.00
# 2        314587  34in Ultrawide Monitor      1                 1      379.99
# 3        315501        Wired Headphones      1                 1       11.99
# 4        312424  AAA Batteries (4-pack)      1                 1        2.99
# ...         ...                     ...    ...               ...         ...
# 24950    297481   AA Batteries (4-pack)      1                 1        3.84
# 24951    298406  AAA Batteries (4-pack)      1                 2        2.99
# 24952    317048  AAA Batteries (4-pack)      1                 2        2.99
# 24953    309773  AAA Batteries (4-pack)      1                 1        2.99
# 24954    297674  AAA Batteries (4-pack)      1                 1        2.99
#
# ...

# %%
dec.to_csv('dec')

# %%
july = pd.read_csv('/content/Sales_July_2019.csv')

# %%
july
# Out:
#       Order ID                     Product  lenth Quantity Ordered Price Each  \
# 0       223058  Bose SoundSport Headphones    1.0                1      99.99
# 1       223043    Lightning Charging Cable    1.0                1      14.95
# 2       223093       AA Batteries (4-pack)    1.0                1       3.84
# 3       222955        USB-C Charging Cable    1.0                1      11.95
# 4       223023  Bose SoundSport Headphones    1.0                1      99.99
# ...        ...                         ...    ...              ...        ...
# 14366   236665            Wired Headphones    NaN                1      11.99
# 14367   236666                20in Monitor    NaN                1     109.99
# 14368   236667      AAA Batteries (4-pack)    NaN                1       2.99
# 14369   236668            Wired Headphones    NaN                1      11.99
# 14370   236669      AAA Batteries (4-pack)    NaN                1       2.99
#
# ...

# %%
july.isnull().sum()
# Out:
# Order ID               45
# Product                45
# lenth               14172
# Quantity Ordered       45
# Price Each             45
# Total               14172
# Month               14172
# Order Date             45
# Purchase Address       45
# Country                80
# State                  80
# Number of State        80
# Unnamed: 12         14371
# Unnamed: 13         14371
# Unnamed: 14         14371
# Unnamed: 15         14371
# dtype: int64

# %%
  julyyy = july.drop_duplicates()

# %%
julyyy
# Out:
#       Order ID                     Product  lenth Quantity Ordered Price Each  \
# 0       223058  Bose SoundSport Headphones    1.0                1      99.99
# 1       223043    Lightning Charging Cable    1.0                1      14.95
# 2       223093       AA Batteries (4-pack)    1.0                1       3.84
# 3       222955        USB-C Charging Cable    1.0                1      11.95
# 4       223023  Bose SoundSport Headphones    1.0                1      99.99
# ...        ...                         ...    ...              ...        ...
# 14366   236665            Wired Headphones    NaN                1      11.99
# 14367   236666                20in Monitor    NaN                1     109.99
# 14368   236667      AAA Batteries (4-pack)    NaN                1       2.99
# 14369   236668            Wired Headphones    NaN                1      11.99
# 14370   236669      AAA Batteries (4-pack)    NaN                1       2.99
#
# ...

# %%
julyyyy = julyyy.dropna()

# %%
julyyyy
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, lenth, Quantity Ordered, Price Each, Total, Month, Order Date, Purchase Address, Country, State, Number of State, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15]
# Index: []

# %%
jull
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, lenth, Quantity Ordered, Price Each, Total, Month, Order Date, Purchase Address, Country, State, Number of State, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15]
# Index: []
